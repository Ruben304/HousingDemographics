# %%
import pandas as pd
from matplotlib import pyplot

# %%
df = pd.read_csv('merged_data.csv', dtype={'Zipcode': str})

# %%
df.head(20)
# Out:
#    Zipcode State     City            Metro        CountyName  Year  \
# 0    01001    MA   Agawam  Springfield, MA    Hampden County  2012
# 1    01001    MA   Agawam  Springfield, MA    Hampden County  2013
# 2    01001    MA   Agawam  Springfield, MA    Hampden County  2014
# 3    01001    MA   Agawam  Springfield, MA    Hampden County  2015
# 4    01001    MA   Agawam  Springfield, MA    Hampden County  2016
# 5    01001    MA   Agawam  Springfield, MA    Hampden County  2017
# 6    01001    MA   Agawam  Springfield, MA    Hampden County  2018
# 7    01001    MA   Agawam  Springfield, MA    Hampden County  2019
# 8    01001    MA   Agawam  Springfield, MA    Hampden County  2020
# 9    01001    MA   Agawam  Springfield, MA    Hampden County  2021
# 10   01001    MA   Agawam  Springfield, MA    Hampden County  2022
# 11   01002    MA  Amherst  Springfield, MA  Hampshire County  2012
# 12   01002    MA  Amherst  Springfield, MA  Hampshire County  2013
# ...

# %%
df.describe(include='all')
# Out:
#        Zipcode   State      City                                  Metro  \
# count   250126  250126    240824                                 207393
# unique   25066      51     12148                                    925
# top      99901      NY  New York  New York-Newark-Jersey City, NY-NJ-PA
# freq        11   16913      1848                                   9000
# mean       NaN     NaN       NaN                                    NaN
# std        NaN     NaN       NaN                                    NaN
# min        NaN     NaN       NaN                                    NaN
# 25%        NaN     NaN       NaN                                    NaN
# 50%        NaN     NaN       NaN                                    NaN
# 75%        NaN     NaN       NaN                                    NaN
# max        NaN     NaN       NaN                                    NaN
#
#                 CountyName           Year     GrowthRate          WHITE  \
# ...

# %%
hist = df.hist(bins=10)
pyplot.tight_layout()
pyplot.show()

# %%
df.plot(x='Year', y='GrowthRate', style='o')
# Out:
# <Axes: xlabel='Year'>
